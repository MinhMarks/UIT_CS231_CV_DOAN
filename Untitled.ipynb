# %%
from PIL import Image

# Mở ảnh
image = Image.open('Bangkok_0000001_2016_11_228_13.71541995884607_100.4848799365689_8hQkYBLClYeLNAEhsfdSFw.jpg')

# Resize ảnh về 64x64
resized_image = image.resize((112, 112))

# Lưu lại (tuỳ chọn)
resized_image.save('resized_image.jpg')

# Nếu muốn hiển thị ảnh sau khi resize
resized_image.show()
# Out:
# <PIL.Image.Image image mode=RGB size=112x112>
